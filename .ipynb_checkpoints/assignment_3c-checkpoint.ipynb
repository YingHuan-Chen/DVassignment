# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import pickle

def build_model():
    model =keras.models.Sequential([
        keras.layers.Flatten(input_shape=(48,48,3)),
        keras.layers.Dense(256,activation=tf.nn.relu),
        keras.layers.Dense(128,activation=tf.nn.relu),
        keras.layers.Dense(2,activation=tf.nn.softmax)
    ])
    return model

if __name__ == '__main__':
  
    data = pickle.load(open("dogs_cats.pkl","rb"))
    X_train, Y_train, X_test, Y_test = data["X_train"], data["Y_train"], data["X_test"], data["Y_test"]
    X_train = X_train / 255.0
    X_test = X_test / 255.0
    
    print(X_train.shape)
    print(Y_train.shape)
    print(X_test.shape)
    print(Y_test.shape) 
    
    model=build_model()
    model.summary()
    model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
    model.fit(X_train,Y_train,epochs=20)
    train_loss,train_acc =model.evaluate(X_train,Y_train)
    test_loss,test_acc =model.evaluate(X_test,Y_test)
    print('Train_acc:',train_acc)
    print('Test_acc:',test_acc)
# Out:
# (4986, 48, 48, 3)
# (4986,)
# (497, 48, 48, 3)
# (497,)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 6912)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               1769728
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 1,802,882
# Trainable params: 1,802,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.8999 - accuracy: 0.5245
# Epoch 2/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.7097 - accuracy: 0.5463
# Epoch 3/20
# 156/156 [==============================] - 1s 7ms/step - loss: 0.6854 - accuracy: 0.5495
# Epoch 4/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6699 - accuracy: 0.5866
# Epoch 5/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6627 - accuracy: 0.6063
# Epoch 6/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6652 - accuracy: 0.6007
# Epoch 7/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6474 - accuracy: 0.6241
# Epoch 8/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6709 - accuracy: 0.5750
# Epoch 9/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6683 - accuracy: 0.5868
# Epoch 10/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6675 - accuracy: 0.5834
# Epoch 11/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6639 - accuracy: 0.5866
# Epoch 12/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6593 - accuracy: 0.5981
# Epoch 13/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6523 - accuracy: 0.6229
# Epoch 14/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6465 - accuracy: 0.6229
# Epoch 15/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6364 - accuracy: 0.6370
# Epoch 16/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6414 - accuracy: 0.6292
# Epoch 17/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6357 - accuracy: 0.6396
# Epoch 18/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6334 - accuracy: 0.6454
# Epoch 19/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6271 - accuracy: 0.6450
# Epoch 20/20
# 156/156 [==============================] - 1s 6ms/step - loss: 0.6274 - accuracy: 0.6434
# 156/156 [==============================] - 0s 2ms/step - loss: 0.6045 - accuracy: 0.6787
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6589 - accuracy: 0.6278
# Train_acc: 0.6787003874778748
# Test_acc: 0.6277666091918945

# %%
# The test accuracy is much lower than the training accuracy. Why?
# How can we improve the test accuracy?
# Write down your answer here.
